# %%
import pandas as pd
import numpy as np

# %%
d1 = pd.read_csv('FOOD-DATA-GROUP1.csv')
d2 = pd.read_csv('FOOD-DATA-GROUP2.csv')

# %%
pd.merge(d1,d2,how='outer')
# Out:
#      Unnamed: 0.1  Unnamed: 0                              food  \
# 0               0           0                      cream cheese
# 1               1           1                 neufchatel cheese
# 2               2           2  requeijao cremoso light catupiry
# 3               3           3                    ricotta cheese
# 4               4           4              cream cheese low fat
# ..            ...         ...                               ...
# 865           314         314                    fontina cheese
# 866           315         315           monterey cheese low fat
# 867           316         316                      colby cheese
# 868           317         317                   american cheese
# 869           318         318                       blue cheese
#
#      Caloric Value   Fat  Saturated Fats  Monounsaturated Fats  \
# 0               51   5.0             2.9                   1.3
# 1              215  19.4            10.9                   4.9
# ...
