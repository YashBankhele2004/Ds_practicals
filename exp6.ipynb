# %% [markdown]
# <a href="https://colab.research.google.com/github/DhananjaySurvase/Data-Science-/blob/main/exp6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib
df= pd.read_csv ("/content/cats_dataset.csv")
df
# Out:
#                   Breed  Age (Years)  Weight (kg)          Color  Gender
# 0          Russian Blue           19            7  Tortoiseshell  Female
# 1      Norwegian Forest           19            9  Tortoiseshell  Female
# 2             Chartreux            3            3          Brown  Female
# 3               Persian           13            6          Sable  Female
# 4               Ragdoll           10            8          Tabby    Male
# ..                  ...          ...          ...            ...     ...
# 995   British Shorthair           19            5           Gray  Female
# 996   British Shorthair           11            2        Bicolor  Female
# 997            Savannah           12            5        Bicolor  Female
# 998  American Shorthair            8            3  Tortoiseshell  Female
# 999           Chartreux           11            4          Sable  Female
#
# [1000 rows x 5 columns]

# %%
import matplotlib.pyplot as plt


plt.hist(df['Age (Years)'], bins=range(0, 21, 1), edgecolor='black')
plt.xlabel('Age (Years)')
plt.ylabel('Frequency')
plt.title('Distribution of Cat Ages')
plt.show()

# %%
plt.scatter(df['Age (Years)'], df['Weight (kg)'])
plt.xlabel('Age (Years)')
plt.ylabel('Weight (kg)')
plt.title('Weight vs. Age of Cats')
plt.show()

# %%
#line chart xlable,line marker , legent , count plot,

# %%
#scater plot , bar plot, histogram, linr chart , box plot

# %%
avg_weights = df.groupby('Breed')['Weight (kg)'].mean()
avg_weights.plot(kind='bar')
plt.xlabel('Breed')
plt.ylabel('Average Weight (kg)')
plt.title('Average Weight by Cat Breed')
plt.xticks(rotation=45)
plt.show()

# %%
avg_weight_by_age = df.groupby('Age (Years)')['Weight (kg)'].mean()

plt.plot(avg_weight_by_age.index, avg_weight_by_age.values, marker='o', linestyle='-', color='b')
plt.xlabel('Age (Years)')
plt.ylabel(' Weight (kg)')
plt.title('Weight by Age')
plt.grid(True)
plt.show()

# %%
bins = range(0, df['Age (Years)'].max() + 1, 2)
df['Age Group'] = pd.cut(df['Age (Years)'], bins=bins)

plt.figure(figsize=(12, 6))
df.boxplot(column='Weight (kg)', by='Age Group', grid=False)
plt.xlabel('Age Group')
plt.ylabel('Weight (kg)')
plt.title('Weight Distribution by Age Group')
plt.suptitle('')
plt.xticks(rotation=45)
plt.show()
